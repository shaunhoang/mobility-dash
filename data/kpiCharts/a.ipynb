# %%
import pandas as pd

# %%
bus_dict = {
    2011: 250,
    2012: 270,
    2013: 290,
    2014: 310,
    2015: 330,
    2016: 364,
    2017: 386,
    2018: 408,
    2019: 230,
    2020: 180,
    2021: 220,
    2022: 210,
    2024: 200,
    2025: 155
}

pop_dict = {
    2011: 3046163,
    2012: 3132000,
    2013: 3224000,
    2014: 3319000,
    2015: 3416000,
    2016: 3514000,
    2017: 3614000,
    2018: 3716000,
    2019: 3820000,
    2020: 3888000,
    2021: 3960000,
    2022: 4078000,
    2023: 4200000,
    2024: 4326000,
    2025: 4455000
}  

# Calculate bus per per key
calc_dict = { 
    year: round(bus_dict[year] / (pop_dict[year] /100000),2) for year in bus_dict
}

# %%
# Calculate bus per per key
df = pd.DataFrame(list(calc_dict.items()), columns=['year', 'value'])
df.to_json('A01.json', orient='records')
